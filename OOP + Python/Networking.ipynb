# %% [markdown]
# # URL

# %%
import urllib.request

# %%
try:
    url = urllib.request.urlopen('https://www.python.org/')
    content = url.read()
except urllib.error.HTTPError:
    print('The web page is not found')
    exit()
    
f = open('Python.html', 'wb')
f.write(content)
f.close()

# %% [markdown]
# # Images

# %%
import urllib.request

# %%
url = 'https://www.python.org/psf-landing/'
urllib.request.urlretrieve(url, 'python.png')
# Out:
# ('python.png', <http.client.HTTPMessage at 0x25be5f704c8>)

# %% [markdown]
# # Socket Programming

# %% [markdown]
# - client: socket, connect, send/recv, close
# - server: socket, bind, listen,, accept, send/recv, close

# %% [markdown]
# ### Create a Server

# %%
import socket
host = 'localhost'
port = 4000
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

s.bind((host, port))
s.listen(1)

c, addr = s.accept()
print('server listening on port: ', port)

print('Connection from:', str(addr))

c.send('Hello, how are you')
c.send('Bye', encode())
c.close()

# %%
# Create Server

# %%
import socket

s = socket.socket()

s.connect(('localhost', 4000))
msg = s.recv(1024)

while msg:
    print('Received', msg.decode())
    msg = s.recv(1024)
    
s.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-6-47e3955cc55c> in <module>
#       3 s = socket.socket()
#       4
# ----> 5 s.connect(('localhost', 4000))
#       6 msg = s.recv(1024)
#       7
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %% [markdown]
# ## Create a client

# %%
import socket
host = 'localhost'
port = 4000

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((host, port))
print('Server listening on port', port)
s.listen()

c, addr = s.accept()

f = file_name = c.recv(1024)
try:
    open(file_name, 'r')
    content - f.read()
    c.send(content)
    f.close()
except FileNotFoundError:
    print('File does not exist')
    
c.close()

# %% [markdown]
# # File Client:

# %%
import socket

s = socket.socket()

s.connect(('localhost', 4000))
file_name = input('Enter a file name: ')
s.send(file_name.encode())
content = s.recv(1024)
print(content.decode())
    
s.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-1-56a07a611a7b> in <module>
#       3 s = socket.socket()
#       4
# ----> 5 s.connect(('localhost', 4000))
#       6 file_name = input('Enter a file name: ')
#       7 s.send(file_name.encode())
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %% [markdown]
# # Sending Emails:

# %%
import smtplib
from email.mime.text import MIMEText

body = 'This is a test email. How are you.'

msg = MIMEText(body)

msg['From'] = 'n.nikolaev.work@gmail.com'
msg['To'] = 'nikolay.nikolaev.audiology@gmail.com'
msg['Subject'] = 'Hello'

server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login('n.nikolaev.work@gmail.com', 'Ialokin1982')
server.send(msg)
print('Mail sent')
server.quit()
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-4-e6380a356016> in <module>
#      12 server = smtplib.SMTP('smtp.gmail.com', 587)
#      13 server.starttls()
# ---> 14 server.login('n.nikolaev.work@gmail.com','Ialokin1982')
#      15 server.send(msg)
#      16 print('Mail sent')
#
# ~\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# ~\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# --> 721                     initial_response_ok=initial_response_ok)
# ...
