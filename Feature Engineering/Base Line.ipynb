# %%
import pandas as pd

# %%
ks = pd.read_csv('data/ks-projects-201801.csv')
ks.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
print("Unique values in 'state' column:", list(ks.state.unique()))
# Out:
# Unique values in 'state' column: ['failed', 'canceled', 'successful', 'live', 'undefined', 'suspended']

# %% [markdown]
# ### Prapare the target column
# -  dropping projects that are 'live'
# - counting 'successful' states as outvome = 1
# - counting every other state as outcome = 0

# %%
# Drop live projects
ks = ks.query('state != "live"')

# Add outcome column, "successful" == 1, others are 0
ks = ks.assign(outcome=(ks['state'] == 'successful').astype(int))

# %% [markdown]
# ### COnvert timestamps

# %%
ks = ks.assign(hour=ks.launched.dt.hour,
               day=ks.launched.dt.day,
               month=ks.launched.dt.month,
               year=ks.launched.dt.year)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-16f74ff1052b> in <module>
# ----> 1 ks = ks.assign(hour=ks.launched.dt.hour,
#       2                day=ks.launched.dt.day,
#       3                month=ks.launched.dt.month,
#       4                year=ks.launched.dt.year)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# ...

# %%
from sklearn.preprocessing import LabelEncoder

cat_features = ['category', 'currency', 'country']
encoder = LabelEncoder()

# Apply the label encoder to each column
encoded = ks[cat_features].apply(encoder.fit_transform)

# %%
# Since ks and encoded have the same index and I can easily join them
data = ks[['goal', 'hour', 'day', 'month', 'year', 'outcome']].join(encoded)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-e64c83861a0d> in <module>
#       1 # Since ks and encoded have the same index and I can easily join them
# ----> 2 data = ks[['goal', 'hour', 'day', 'month', 'year', 'outcome']].join(encoded)
#       3 data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
## Create training, validation and test split

# %%
valid_fraction = 0.1
valid_size = int(len(data) * valid_fraction)

train = data[:-2 * valid_size]
valid = data[-2 * valid_size:-valid_size]
test = data[-valid_size:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-778605a7a7d9> in <module>
#       1 valid_fraction = 0.1
# ----> 2 valid_size = int(len(data) * valid_fraction)
#       3
#       4 train = data[:-2 * valid_size]
#       5 valid = data[-2 * valid_size:-valid_size]
#
# NameError: name 'data' is not defined

# %%
## Train a model

# %%
import lightgbm as lgb

feature_cols = train.columns.drop('outcome')

dtrain = lgb.Dataset(train[feature_cols], label=train['outcome'])
dvalid = lgb.Dataset(valid[feature_cols], label=valid['outcome'])

param = {'num_leaves': 64, 'objective': 'binary'}
param['metric'] = 'auc'
num_round = 1000
bst = lgb.train(param, dtrain, num_round, valid_sets=[dvalid], early_stopping_rounds=10, verbose_eval=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-98e7ed789765> in <module>
#       1 import lightgbm as lgb
#       2
# ----> 3 feature_cols = train.columns.drop('outcome')
#       4
#       5 dtrain = lgb.Dataset(train[feature_cols], label=train['outcome'])
#
# NameError: name 'train' is not defined

# %% [markdown]
# ## Make predictions and evaluete the model

# %%
from sklearn import metrics
ypred = bst.predict(test[feature_cols])
score = metrics.roc_auc_score(test['outcome'], ypred)

print(f"Test AUC score: {score}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-def84352edea> in <module>
#       1 from sklearn import metrics
# ----> 2 ypred = bst.predict(test[feature_cols])
#       3 score = metrics.roc_auc_score(test['outcome'], ypred)
#       4
#       5 print(f"Test AUC score: {score}")
#
# NameError: name 'bst' is not defined
