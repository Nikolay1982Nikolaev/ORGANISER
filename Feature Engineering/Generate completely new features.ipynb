# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing, metrics
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
ks = pd.read_csv('data/ks-projects-201801.csv')
ks.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %%
interactions = ks['category'] + "_" + ks['country']
print(interactions.head(5))
# Out:
# 0            Poetry_GB
# 1    Narrative Film_US
# 2    Narrative Film_US
# 3             Music_US
# 4      Film & Video_US
# dtype: object

# %%
label_enc = LabelEncoder()
data_interaction = baseline_data.assign(category_country=label_enc.fit_transform(interactions))
data_interaction.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e7848b9fa14d> in <module>
#       1 label_enc = LabelEncoder()
# ----> 2 data_interaction = baseline_data.assign(category_country=label_enc.fit_transform(interactions))
#       3 data_interaction.head()
#
# NameError: name 'baseline_data' is not defined

# %%
Number of projects in the last week
# Out:
#   File "<ipython-input-15-aaf029abfbfe>", line 1
#     Number of projects in the last week
#             ^
# SyntaxError: invalid syntax

# %%
# First, create a Series with a timestamp index
launched = pd.Series(ks.index, index=ks.launched, name="count_7_days").sort_index()
launched.head(20)
# Out:
# launched
# 1970-01-01 01:00:00     75397
# 1970-01-01 01:00:00    319002
# 1970-01-01 01:00:00      2842
# 1970-01-01 01:00:00     94579
# 1970-01-01 01:00:00    247913
# 1970-01-01 01:00:00    273779
# 1970-01-01 01:00:00     48147
# 2009-04-21 21:02:48    169268
# 2009-04-23 00:07:53    322000
# 2009-04-24 21:52:03    138572
# 2009-04-25 17:36:21    325391
# 2009-04-27 14:10:39    122662
# 2009-04-28 13:55:41    213711
# 2009-04-29 02:04:21    345606
# 2009-04-29 02:58:50    235255
# 2009-04-29 04:37:37     98954
# 2009-04-29 05:26:32    342226
# 2009-04-29 06:43:44    275091
# 2009-04-29 13:52:03    284115
# 2009-04-29 22:08:13     32898
# Name: count_7_days, dtype: int64

# %%
count_7_days = launched.rolling('7d').count() - 1
print(count_7_days.head(20))

# Ignore records with broken launch dates
plt.plot(count_7_days[7:]);
plt.title("Number of projects launched over periods of 7 days");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-7a10412a2659> in <module>
# ----> 1 count_7_days = launched.rolling('7d').count() - 1
#       2 print(count_7_days.head(20))
#       3
#       4 # Ignore records with broken launch dates
#       5 plt.plot(count_7_days[7:]);
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in rolling(self, window, min_periods, center, win_type, on, axis, closed)
#   10767                 on=on,
#   10768                 axis=axis,
# > 10769                 closed=closed,
#   10770             )
#   10771
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in rolling(obj, win_type, **kwds)
#    2847         return Window(obj, win_type=win_type, **kwds)
#    2848
# -> 2849     return Rolling(obj, **kwds)
#    2850
#    2851
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in __init__(self, obj, window, min_periods, center, win_type, axis, on, closed, **kwargs)
#      91         self.win_freq = None
#      92         self.axis = obj._get_axis_number(axis) if axis is not None else None
# ---> 93         self.validate()
#      94
#      95     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in validate(self)
#    1736
#    1737         elif not is_integer(self.window):
# -> 1738             raise ValueError("window must be an integer")
#    1739         elif self.window < 0:
#    1740             raise ValueError("window must be non-negative")
#
# ValueError: window must be an integer

# %%
count_7_days.index = launched.values
count_7_days = count_7_days.reindex(ks.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2435539b1e83> in <module>
# ----> 1 count_7_days.index = launched.values
#       2 count_7_days = count_7_days.reindex(ks.index)
#
# NameError: name 'count_7_days' is not defined

# %%
count_7_days.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6e5618feb857> in <module>
# ----> 1 count_7_days.head(10)
#
# NameError: name 'count_7_days' is not defined

# %%
baseline_data.join(count_7_days).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c6a9b6bef15b> in <module>
# ----> 1 baseline_data.join(count_7_days).head(10)
#
# NameError: name 'baseline_data' is not defined

# %%
Time since the last project in the same category
# Out:
#   File "<ipython-input-21-9bf9ad8ba6ec>", line 1
#     Time since the last project in the same category
#              ^
# SyntaxError: invalid syntax

# %%
def time_since_last_project(series):
    # Return the time in hours
    return series.diff().dt.total_seconds() / 3600.

df = ks[['category', 'launched']].sort_values('launched')
timedeltas = df.groupby('category').transform(time_since_last_project)
timedeltas.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _transform_general(self, func, *args, **kwargs)
#     530                 try:
# --> 531                     path, res = self._choose_path(fast_path, slow_path, group)
#     532                 except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _choose_path(self, fast_path, slow_path, group)
#     632         path = slow_path
# --> 633         res = slow_path(group)
#     634
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in <lambda>(group)
#     626             slow_path = lambda group: group.apply(
# --> 627                 lambda x: func(x, *args, **kwargs), axis=self.axis
#     628             )
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6912         )
# -> 6913         return op.get_result()
#    6914
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     185
# --> 186         return self.apply_standard()
#     187
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in <lambda>(x)
#     626             slow_path = lambda group: group.apply(
# --> 627                 lambda x: func(x, *args, **kwargs), axis=self.axis
#     628             )
#
# <ipython-input-22-ac3ebbf54fb2> in time_since_last_project(series)
#       2     # Return the time in hours
# ----> 3     return series.diff().dt.total_seconds() / 3600.
#       4
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in diff(self, periods)
#    2550         """
# -> 2551         result = algorithms.diff(com.values_from_object(self), periods)
#    2552         return self._constructor(result, index=self.index).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in diff(arr, n, axis)
#    1976         else:
# -> 1977             out_arr[res_indexer] = arr[res_indexer] - arr[lag_indexer]
#    1978
#
# TypeError: ("unsupported operand type(s) for -: 'str' and 'str'", 'occurred at index launched')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ac3ebbf54fb2> in <module>
#       4
#       5 df = ks[['category', 'launched']].sort_values('launched')
# ----> 6 timedeltas = df.groupby('category').transform(time_since_last_project)
#       7 timedeltas.head(20)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in transform(self, func, *args, **kwargs)
#     582                 result = getattr(self, func)(*args, **kwargs)
#     583         else:
# --> 584             return self._transform_general(func, *args, **kwargs)
#     585
#     586         # a reduction transform
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _transform_general(self, func, *args, **kwargs)
#     531                     path, res = self._choose_path(fast_path, slow_path, group)
#     532                 except TypeError:
# --> 533                     return self._transform_item_by_item(obj, fast_path)
#     534                 except ValueError:
#     535                     msg = "transform must return a scalar value for each group"
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _transform_item_by_item(self, obj, wrapper)
#     664
#     665         if len(output) == 0:  # pragma: no cover
# --> 666             raise TypeError("Transform function invalid for data types")
#     667
#     668         columns = obj.columns
#
# TypeError: Transform function invalid for data types

# %%
# Final time since last project
timedeltas = timedeltas.fillna(timedeltas.median()).reindex(baseline_data.index)
timedeltas.head(20)

# %%
Transforming numerical features
# Out:
#   File "<ipython-input-23-70cb825ddb25>", line 1
#     Transforming numerical features
#                          ^
# SyntaxError: invalid syntax

# %%
plt.hist(ks.goal, range=(0, 100000), bins=50);
plt.title('Goal');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ab6c7959aa6a> in <module>
# ----> 1 plt.hist(ks.goal, range=(0, 100000), bins=50);
#       2 plt.title('Goal');
#
# NameError: name 'plt' is not defined

# %%
plt.hist(np.sqrt(ks.goal), range=(0, 400), bins=50);
plt.title('Sqrt(Goal)');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8f2acea9a162> in <module>
# ----> 1 plt.hist(np.sqrt(ks.goal), range=(0, 400), bins=50);
#       2 plt.title('Sqrt(Goal)');
#
# NameError: name 'plt' is not defined

# %%
plt.hist(np.log(ks.goal), range=(0, 25), bins=50);
plt.title('Log(Goal)');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-cc6a01c07bb3> in <module>
# ----> 1 plt.hist(np.log(ks.goal), range=(0, 25), bins=50);
#       2 plt.title('Log(Goal)');
#
# NameError: name 'plt' is not defined
