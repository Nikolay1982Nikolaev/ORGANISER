# %% [markdown]
# ### 7 steps of ML
# 1. Gather the data
# 2. Prepare the data
# 3. Prepare the data: dela with missing values and categorical data (Feature Engineering)
# 4. Train the model - fit decision trees and random forests
# 5. Evaluate the model - use a validation set to access how well a train model performs on unseen data
# 6. Tune parameters: tune parameters to get better performance from XCBoost models
# 7. Get predictions: generatepredictions with a trained model and submit you results
