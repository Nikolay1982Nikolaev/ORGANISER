# %% [markdown]
# ## Abstraction

# %%
from abc import ABC, abstractmethod

class BMW(ABC):
    
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    
    def start(self):
        print('Starting the car')
        
    def stop(self):
        print('Stopping the car')
    
    @abstractmethod
    def drive(self):  
        pass


class ThreeSeries(BMW):
    def __init__(self, cruise_control, make, model, year):
        super().__init__(make, model, year)
        self.cruise_control = cruise_control
        
    def display(self):
        print(self.cruise_control)
        
    def start(self):
        super().start()
        print('Button Start')

    def drive(self):
        print('Three Series is being driven')
        
class FiveSeries(BMW):
    def __init__(self, parking_assistant, make, model, year):
        super().__init__(make, model, year)
        self.parking_assistant = parking_assistant
        
    def drive(self):
        print('Five Series is being driven')
        
        
        
three_s = ThreeSeries(True, 'BMW', '328i', 2018)
print(three_s.cruise_control)
print(three_s.make)
print(three_s.model)
print(three_s.year)

three_s.start()
three_s.stop()
three_s.display()


three_s.drive()
# Out:
# True
# BMW
# 328i
# 2018
# Starting the car
# Button Start
# Stopping the car
# True
# Three Series is being driven

# %% [markdown]
# ### Create an Interface

# %%
from abc import ABC, abstractmethod

class BMW(ABC):
    
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    
    @abstractmethod
    def start(self):
        pass
    
    @abstractmethod
    def stop(self):
        pass
    
    @abstractmethod
    def drive(self):  
        pass


class ThreeSeries(BMW):
    def __init__(self, cruise_control, make, model, year):
        super().__init__(make, model, year)
        self.cruise_control = cruise_control
        
    def display(self):
        print(self.cruise_control)
        
    def start(self):
        super().start()
        print('Button Start')
        
    def stop(self):
        super().stop()
        print('Button Stop')

    def drive(self):
        print('Three Series is being driven')
        
        
class FiveSeries(BMW):
    def __init__(self, parking_assistant, make, model, year):
        super().__init__(make, model, year)
        self.parking_assistant = parking_assistant
        
    def drive(self):
        print('Five Series is being driven')
        
    def start(self):
        super().start()
        print('Button Start')
        
    def stop(self):
        super().stop()
        print('Button Stop')
        
        
        
three_s = ThreeSeries(True, 'BMW', '328i', 2018)
print(three_s.cruise_control)
print(three_s.make)
print(three_s.model)
print(three_s.year)

three_s.start()
three_s.stop()
three_s.display()


three_s.drive()
# Out:
# True
# BMW
# 328i
# 2018
# Button Start
# Button Stop
# True
# Three Series is being driven
