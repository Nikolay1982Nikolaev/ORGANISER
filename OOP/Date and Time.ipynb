# %%
# Current Data and Time
# Compining Data and Time

# %%
import time

# %%
epoch = time.time()
print(epoch)
# Out:
# 1599427185.9853141

# %%
t = time.ctime(epoch)
print(t)
# Out:
# Sun Sep  6 23:19:45 2020

# %%
# finding the current date and time
import data

dt = datetime.datetime.today()
print(dt.day, dt.month, dt.year)
print(dt.hour, dt.minute, dt.year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c68cf2f1b083> in <module>
#       1 # finding the current date and time
# ----> 2 dt = datetime.datetime.today()
#       3 print(dt.day, dt.month, dt.year)
#       4 print(dt.hour, dt.minute, dt.year)
#
# NameError: name 'datetime' is not defined
